# %% [markdown]
# <a href="https://colab.research.google.com/github/Reet1992/Deep_learning_R/blob/main/simple_box_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install cvlib
# Out:
# ...
#      |████████████████████████████████| 10.1MB 3.8MB/s
# ...
#   Created wheel for cvlib: filename=cvlib-0.2.5-cp36-none-any.whl size=10044206 sha256=721583a6a5c03e77eb23c1450b725238b6292357fa5a1dbec4d9c6c3df4f6e56
#   Stored in directory: /root/.cache/pip/wheels/6a/cb/43/ba188c823836640d8f22ee1f6ff792a0c83a8b66eabf52b219
# ...
#   Created wheel for progressbar: filename=progressbar-2.5-cp36-none-any.whl size=12076 sha256=5f05621cb3128f002de937f3edf41b73342191ec66b34cb204e9addda7cfffc3
#   Stored in directory: /root/.cache/pip/wheels/c0/e9/6b/ea01090205e285175842339aa3b491adeb4015206cda272ff0
# Successfully built cvlib progressbar
# ...

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox

# %%
im = cv2.imread('/content/drive/MyDrive/data/cars.JPG')

img_gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY) 
img_rgb = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

# %%
bbox, label, conf = cv.detect_common_objects(im)
# Out:
# ...
#   0% |                                                                        |
# ...

# %%
output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()

# %%
#### EXtract Gif Images 

import imageio
import urllib.request
url = "http://rebloggy.com/post/my-gif-gif-cars-jaguar-drift-v8-jaguar-f-type/99677904600"
fname = "tmp.gif" 

imdata = urllib.request.urlopen(url).read()
imbytes = bytearray(imdata)
open(fname,"wb+").write(imdata)
# Out:
# 56351
